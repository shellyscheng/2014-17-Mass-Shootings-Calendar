# %% [markdown]
# # 2017 Shooting Data Analysis
#
# Data Source: http://www.gunviolencearchive.org/

# %%
import pandas as pd
df = pd.read_csv("2017MassShooting.csv")
df.head()
# Out:
#   Incident Date         State City Or County                   Address  \
# 0       12/6/17      Illinois        Chicago           4620 N Broadway
# 1       12/4/17  Pennsylvania     Pittsburgh  7200 block of Everton St
# 2       12/3/17     Tennessee        Memphis          656 Marshall Ave
# 3       12/2/17      Michigan        Detroit      5200 Woodward Avenue
# 4      11/30/17      Michigan        Detroit    11000 block of Gunston
#
#    # Killed  # Injured  Operations
# 0         0          4         NaN
# 1         2          2         NaN
# 2         1          3         NaN
# 3         0          4         NaN
# 4         1          4         NaN

# %%
df.dtypes
# Out:
# Incident Date      object
# State              object
# City Or County     object
# Address            object
# # Killed            int64
# # Injured           int64
# Operations        float64
# dtype: object

# %%
df['Date'] = pd.to_datetime(df['Incident Date'], format="%m/%d/%y")
df.head()
# Out:
#   Incident Date         State City Or County                   Address  \
# 0       12/6/17      Illinois        Chicago           4620 N Broadway
# 1       12/4/17  Pennsylvania     Pittsburgh  7200 block of Everton St
# 2       12/3/17     Tennessee        Memphis          656 Marshall Ave
# 3       12/2/17      Michigan        Detroit      5200 Woodward Avenue
# 4      11/30/17      Michigan        Detroit    11000 block of Gunston
#
#    # Killed  # Injured  Operations       Date
# 0         0          4         NaN 2017-12-06
# 1         2          2         NaN 2017-12-04
# 2         1          3         NaN 2017-12-03
# 3         0          4         NaN 2017-12-02
# 4         1          4         NaN 2017-11-30

# %%
df.tail()
# Out:
#     Incident Date        State City Or County                       Address  \
# 323        1/4/17   California        Fontana           14520 Village Drive
# 324        1/3/17        Texas          Allen  500 block of Hawthorne Drive
# 325        1/1/17  Mississippi   Winstonville       114 North Greyer Street
# 326        1/1/17        Texas         Dallas          9220 Skillman Street
# 327        1/1/17      Florida          Miami     8000 block of NW 14th Ave
#
#      # Killed  # Injured  Operations       Date
# 323         3          1         NaN 2017-01-04
# 324         0          4         NaN 2017-01-03
# 325         0          5         NaN 2017-01-01
# 326         1          3         NaN 2017-01-01
# 327         0          7         NaN 2017-01-01

# %%
df2 = df['Date'].value_counts()
df2.head()
# Out:
# 2017-04-15    6
# 2017-04-29    6
# 2017-08-21    5
# 2017-07-01    4
# 2017-04-07    4
# Name: Date, dtype: int64
